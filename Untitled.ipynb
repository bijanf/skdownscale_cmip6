# %% [markdown]
# # Plotting the results for Zero height isotherm

# %%
# importing 
import matplotlib.pyplot as plt 
import os
import xarray as xr

# %%
# make the percentiles from the netcdf file 
def percentiles_from_nc(file, fileout,pctl0, pctl1,pctl2):
    cmd = "cdo -L -b f32 yearpctl,"+str(pctl0)+" "+file+" -yearmin  "+file+" -yearmax  "+file+" "+fileout+str(pctl0)+".nc"
    os.system(cmd)
    cmd = "cdo -L -b f32 yearpctl,"+str(pctl1)+" "+file+" -yearmin  "+file+" -yearmax  "+file+" "+fileout+str(pctl1)+".nc"
    os.system(cmd)
    cmd = "cdo -L -b f32 yearpctl,"+str(pctl2)+" "+file+" -yearmin  "+file+" -yearmax  "+file+" "+fileout+str(pctl2)+".nc"
    os.system(cmd)
    cmd = "cdo -L -b f32 yearmean,"+str(pctl0)+" "+file+" -yearmin  "+file+" -yearmax  "+file+" "+fileout+str(pctl0)+".nc"
    os.system(cmd)
def early_stats(file, fileout):
    cmd = "cdo -O -L -b f32 yearmean  -selseas,JJAS "+file+" "+fileout
    os.system(cmd)

# %%
#percentiles_from_nc("/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec.nc",
#                    "/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec_pctls",
#                    25, 50,75)
early_stats("/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec.nc",
            "/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec_JJA.nc")
# Out:
# cdo(1) selseason: Process started
# cdo(1) selseason: Processed 1 variable over 12784 timesteps.
# cdo    yearmean: Processed 4270 values from 1 variable over 4304 timesteps [0.26s 28MB].

# %%
# read the data: 

ds_disk_0 = xr.open_dataset("/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec_pctls25.nc").load()
ds_disk_1 = xr.open_dataset("/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec_pctls50.nc").load()
ds_disk_2 = xr.open_dataset("/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec_pctls75.nc").load()

jja = xr.open_dataset("/home/fallah/Documents/SCRIPTS/DeepSD/ploting/output/height_zdi_1980_2016_90arcsec_JJA.nc")

fig, axs = plt.subplots(ncols=2,figsize=(18,6))
#jja.tasmin[:,0,0].plot.line(color='k', marker="o",
#                                  markersize=10,lw=1, markerfacecolor='r',ax=axs[1])
jja.tasmin[:,0,0].plot.line(color='k',lw=2,ax=axs[1])
#ds_disk_1.tasmin[:,0,0].plot.line(color='k',lw=3)
ds_disk_2.tasmin[:,0,0].plot.line(color='k', marker="o",
                                  markersize=10,lw=1, markerfacecolor='y',ax=axs[0])

axs[0].set_title("yearpctl,75");
axs[0].set_ylabel("height [m]", fontsize=20)
axs[0].set_xlabel("Time", fontsize=20)

axs[1].set_title("JJA mean", fontsize=20);
axs[1].set_ylabel("height [m]", fontsize=20)
axs[1].set_xlabel("Time", fontsize=20)

plt.tight_layout()
ds_disk_0.close()
ds_disk_1.close()
ds_disk_2.close()
jja.close()

# %% [markdown]
# ## Calculate the zero height isotherm from historical runs of CMIP6

# %%
import matplotlib.pyplot as plt
import os 
import xarray as xr
import numpy as np
import glob
def zero_isotherm_ts(topo="../chelsa-w5e5v1.0_obsclim_orog_90arcsec_Zarafshan.nc",
                     temp='../outputs/chelsa_CA_1980_2014_JJA.nc', delta=.1):
    
    '''
    This function calculates the height of the zero isotherm (the altitude at which the temperature is 0°C) using two input NetCDF files,
    one containing topography data and another containing minimum daily temperature data.
    The function uses the xarray library to open and load the data from the input files.
    It then extracts the topography data from the orog variable in the topo_data object,
    and the minimum daily temperature data from the tasmin variable in the temp_data object.
    The function then calculates the zero height isotherm by finding the nearest height to zero
    for each time step in the minimum daily temperature data. It does this by using numpy's 
    percentile function to find the 50th percentile (i.e. the median) of the topography data
    within a range of +/- delta around 273.15 K (0°C), where delta is a user-defined parameter.
    The function returns an array of the same length as the number of time steps in the input
    temperature data, containing the height of the zero isotherm at each time step.
    Note that the function assumes that the input NetCDF files are structured in a specific way,
    with the topography data stored in the orog variable and the minimum daily temperature data stored
    in the tasmin variable. If the files have different variable names or structures, 
    the function may need to be modified to extract the appropriate data.
    '''
    
   
    # delta is the range around zero
    delta=delta
    # Load the topography data
    topo_data = xr.open_dataset(topo).load()
    topo = topo_data.orog.values
    
    # Load the minimum daily temperature data
    temp_data = xr.open_dataset(temp).load()
    temp = temp_data.tasmin.values
    temp_data.close()
    # Calculate the zero height isotherm
    # Find the nearest height to zero
    zero_height = np.nan * np.ones(temp.shape[0])
    for i in range(temp.shape[0]):
        zero_height[i] = np.nanpercentile(topo[(temp[i,:,:].squeeze()<=(273.15+delta))  & 
                                         (temp[i,:,:].squeeze()>=(273.15-delta))],50)
    return zero_height

# %%
# 
zero_height = zero_isotherm_ts("../chelsa-w5e5v1.0_obsclim_orog_90arcsec_Zarafshan.nc",
                               "../outputs/chelsa_CA_1980_2014_JJA.nc")
dir_cmip="/home/fallah/Documents/SCRIPTS/DeepSD/notebooks/"
fig, axs = plt.subplots(ncols=2,figsize=(10,6))

counter = 0
zero_height_all = np.nan * np.ones((24,zero_height.shape[0]))
for file in os.listdir(dir_cmip):
    if file.endswith("_1980_2014.nc"):
        
        print(file, " is being processed........")
    
        
        cmd = "cdo -yearmean -selmon,4,5,6,7,8,9 "+dir_cmip+file+" ./"+file+"_AMJJAS.nc"
        os.system(cmd)
        zero_height_hist = zero_isotherm_ts("../chelsa-w5e5v1.0_obsclim_orog_90arcsec_Zarafshan.nc",
                                       "./"+file+"_AMJJAS.nc")
        
        
        
        
        
        
        
        #axs.plot(range(1980,2015),zero_height_hist,'g-',alpha=.31)
        zero_height_all[counter,:] = zero_height_hist
        counter +=1
print(counter,'-------------------')


dir_cmip="/home/fallah/Documents/SCRIPTS/DeepSD/notebooks/"


counter_ssp = 0
zero_height_all_ssp = np.nan * np.ones((4,21,30))
for ssp in ["ssp126","ssp245","ssp370","ssp585"]:
    counter = 0
    for file in os.listdir(dir_cmip):
        if file.endswith("_2070_2099.nc"):
            
            if ssp in file : 
                
            
                print(file, " is being processed........")
            
                
                cmd = "cdo -yearmean -selmon,4,5,6,7,8,9 "+dir_cmip+file+" ./"+file+"_AMJJAS.nc"
                os.system(cmd)
                zero_height_hist = zero_isotherm_ts("../chelsa-w5e5v1.0_obsclim_orog_90arcsec_Zarafshan.nc",
                                               "./"+file+"_AMJJAS.nc")
                
                
                
                
                
                
                
                #axs.plot(range(1980,2015),zero_height_hist,'g-',alpha=.31)
                zero_height_all_ssp[counter_ssp,counter,:] = zero_height_hist
                counter +=1
    counter_ssp +=1  
print(counter,'-------------------')





os.system("rm ./*_AMJJAS.nc")
# Out:
# predicted_CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Process started
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.40s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.AWI.AWI-CM-1-1-MR.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.40s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NCC.NorESM2-LM.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.CCCma.CanESM5.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.44s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NOAA-GFDL.GFDL-ESM4.historical.day.gr1_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.43s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.CSIRO.ACCESS-ESM1-5.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.54s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.MPI-M.MPI-ESM1-2-LR.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.48s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NOAA-GFDL.GFDL-CM4.historical.day.gr2_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.50s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.KIOST.KIOST-ESM.historical.day.gr1_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.44s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.MRI.MRI-ESM2-0.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical.day.gr_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.53s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NOAA-GFDL.GFDL-CM4.historical.day.gr1_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NUIST.NESM3.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NASA-GISS.GISS-E2-1-G.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.EC-Earth-Consortium.EC-Earth3.historical.day.gr_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.42s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.CAS.FGOALS-g3.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.42s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.MPI-M.MPI-ESM1-2-HR.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.INM.INM-CM5-0.historical.day.gr1_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.40s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.MIROC.MIROC6.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.41s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.AWI.AWI-ESM-1-1-LR.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13149 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.40s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.SNU.SAM0-UNICON.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.39s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.INM.INM-CM4-8.historical.day.gr1_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.39s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.BCC.BCC-ESM1.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.39s 33MB].
# cdo(1) selmonth: Process started
# predicted_CMIP.NCC.NorESM2-MM.historical.day.gn_1980_2014.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 13140 timesteps.
# cdo    yearmean: Processed 35838720 values from 1 variable over 6622 timesteps [0.40s 33MB].
# cdo(1) selmonth: Process started
# 24 -------------------
# predicted_ScenarioMIP.CCCma.CanESM5.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.28s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM5-0.ssp126.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM4-8.ssp126.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.38s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp126.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.35s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MIROC.MIROC6.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.34s 25MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp126.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.28s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CMCC.CMCC-ESM2.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.38s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-MM.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.31s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.KIOST.KIOST-ESM.ssp126.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 25MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NUIST.NESM3.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CAS.FGOALS-g3.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.35s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MRI.MRI-ESM2-0.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 25MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp126.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.31s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MRI.MRI-ESM2-0.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 25MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp245.day.gr2_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM5-0.ssp245.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp245.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CCCma.CanESM5.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3-CC.ssp245.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.KIOST.KIOST-ESM.ssp245.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.30s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.31s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp245.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.29s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.44s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CMCC.CMCC-ESM2.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.47s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MIROC.MIROC6.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.43s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp245.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.45s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-MM.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.43s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NUIST.NESM3.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.56s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-LM.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.45s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.44s 25MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM4-8.ssp245.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.43s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.AS-RCEC.TaiESM1.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.47s 25MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CAS.FGOALS-g3.ssp245.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.43s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MIROC.MIROC6.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.46s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.49s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp370.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.46s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp370.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.49s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CMCC.CMCC-ESM2.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.48s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3-AerChem.ssp370.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.43s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MRI.MRI-ESM2-0.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.45s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM5-0.ssp370.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.47s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.44s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM4-8.ssp370.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.47s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-LM.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.51s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CAS.FGOALS-g3.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.45s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-MM.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.50s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CCCma.CanESM5.ssp370.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.42s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.48s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CAS.FGOALS-g3.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.63s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.60s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MIROC.MIROC6.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.72s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CCCma.CanESM5.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.63s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.58s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM5-0.ssp585.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.63s 26MB].
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.68s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MRI.MRI-ESM2-0.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.56s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp585.day.gr_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.57s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-LM.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.62s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.INM.INM-CM4-8.ssp585.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.60s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NCC.NorESM2-MM.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.58s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NUIST.NESM3.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.59s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp585.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.59s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp585.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.60s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.KIOST.KIOST-ESM.ssp585.day.gr1_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.83s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585.day.gn_2070_2099.nc  is being processed........
# cdo(1) selmonth: Processed 1 variable over 10957 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.68s 25MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# cdo(1) selmonth: Process started
# predicted_ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp585.day.gr2_2070_2099.nc  is being processed........
# 18 -------------------
# cdo(1) selmonth: Processed 1 variable over 10950 timesteps.
# cdo    yearmean: Processed 29865600 values from 1 variable over 5519 timesteps [0.65s 26MB].
# /home/fallah/.local/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1372: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# 0

# %%
fig = plt.figure(figsize=(10,5))
gs = fig.add_gridspec(1, 2, hspace=0, wspace=0.04)
(ax1, ax2) = gs.subplots( sharey='row')


ax1.plot(range(1980,2015),np.percentile(zero_height_all,50,axis=0),'m-',
         alpha=1, lw=3, label="historical (24)")
mstd = np.std(zero_height_all,axis=0)

ax1.fill_between(range(1980,2015),np.percentile(zero_height_all,50,axis=0) + mstd,
                np.percentile(zero_height_all,50,axis=0) - mstd,
                color='m', alpha=0.2)
ax1.plot(range(1980,2015),zero_height,'k-', label="CHELSA")
#ax1.set_title("AMJJAS mean", fontsize=20);
ax1.set_ylabel("height [m]", fontsize=20)
#ax1.set_xlabel("Time", fontsize=20)

# SSPs
ssp= ["ssp126 (15)","ssp245 (21)","ssp370 (15)","ssp585 (18)"]
for i in range(4):
    ax2.plot(range(2070,2100),np.nanpercentile(zero_height_all_ssp[i,:,:].squeeze(),50,axis=0),
             alpha=1, lw=3, label=ssp[i])
    mstd = np.nanstd(zero_height_all_ssp[i,:,:].squeeze(),axis=0)

    ax2.fill_between(range(2070,2100),np.nanpercentile(zero_height_all_ssp[i,:,:].squeeze(),
                                                       50,axis=0) + mstd,
                    np.nanpercentile(zero_height_all_ssp[i,:,:].squeeze(),50,axis=0) - mstd,
                    alpha=0.2)
#ax2.set_yticks([])
plt.setp(ax2.get_yticklabels(), visible=True)
ax2.legend(frameon=False, fontsize=15)
ax1.legend(frameon=False, fontsize=15)
ax2.yaxis.tick_right()
ax2.yaxis.set_tick_params(labelright='on')
ax2.yaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax1.xaxis.set_tick_params(labelsize=15)
ax2.xaxis.set_tick_params(labelsize=15)
